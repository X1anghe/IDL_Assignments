# %%
import numpy as np
from keras.datasets import cifar10
from keras.datasets import fashion_mnist
import Mnist_cnn
import Mnist_mlp
import Mnist_cnn_custom
import Mnist_mlp_custom
import Cifar10_cnn
import matplotlib.pyplot as plt

# %% [markdown]
# ---

# %% [markdown]
# ### Data Visualization

# %%
def Data_inform(data):
    print("Sample size: ",data.size)     
    print("Sample Shape: ",data.shape)  
    print("Classes num: ",len(np.unique(data)), '\n')

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

print('minist x_train')
Data_inform(x_train)
print('minist y_train')
Data_inform(y_train)
print('minist x_test')
Data_inform(x_test)
print('minist y_test')
Data_inform(y_test)
# Out:
# minist x_train
# Sample size:  47040000
# Sample Shape:  (60000, 28, 28)
# Classes num:  256
#
# minist y_train
# Sample size:  60000
# Sample Shape:  (60000,)
# Classes num:  10
#
# minist x_test
# Sample size:  7840000
# Sample Shape:  (10000, 28, 28)
# Classes num:  256
#
# minist y_test
# Sample size:  10000
# Sample Shape:  (10000,)
# Classes num:  10

# %%
# (x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('minist x_train')
Data_inform(x_train)
print('minist y_train')
Data_inform(y_train)
print('minist x_test')
Data_inform(x_test)
print('minist y_test')
Data_inform(y_test)
# Out:
# minist x_train
# Sample size:  153600000
# Sample Shape:  (50000, 32, 32, 3)
# Classes num:  256
#
# minist y_train
# Sample size:  50000
# Sample Shape:  (50000, 1)
# Classes num:  10
#
# minist x_test
# Sample size:  30720000
# Sample Shape:  (10000, 32, 32, 3)
# Classes num:  256
#
# minist y_test
# Sample size:  10000
# Sample Shape:  (10000, 1)
# Classes num:  10

# %% [markdown]
# ---

# %% [markdown]
# ### Minist CNN

# %% [markdown]
# ### Original model

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# (x_train, y_train), (x_test, y_test) = cifar10.load_data()

batch_size = 128
num_classes = 10
epochs = 20
ini = ['Ones', 'Zeros', 'RandomUniform', 'RandomNormal']
regu = ['l1', 'l2', 'l1', 'l2']; drop = [True, True, False, False]

acti = ['sigmoid', 'relu', 'tanh', 'softmax']
opti = ['SGD', "Adadelta", 'Adam', 'RMSprop']
cnn_parameters = [ [ini[0], acti[0], opti[0], regu[0], drop[0]],
                    [ini[0], acti[1], opti[1], regu[1], drop[1]],
                    [ini[0], acti[2], opti[2], regu[2], drop[2]],
                    [ini[0], acti[3], opti[3], regu[3], drop[3]],
                    [ini[1], acti[0], opti[1], regu[2], drop[2]],
                    [ini[1], acti[1], opti[0], regu[3], drop[3]],
                    [ini[1], acti[2], opti[3], regu[0], drop[0]],
                    [ini[1], acti[3], opti[2], regu[1], drop[1]],
                    [ini[2], acti[0], opti[2], regu[3], drop[3]],
                    [ini[2], acti[1], opti[3], regu[2], drop[2]],
                    [ini[2], acti[2], opti[0], regu[1], drop[1]],
                    [ini[2], acti[3], opti[1], regu[0], drop[0]],
                    [ini[3], acti[0], opti[3], regu[1], drop[1]],
                    [ini[3], acti[1], opti[2], regu[0], drop[0]],
                    [ini[3], acti[2], opti[1], regu[3], drop[3]],
                    [ini[3], acti[3], opti[0], regu[2], drop[2]],]


# mlp_setups = ['glorot_normal', 'relu', 'rmsprop', 'l2']

# mnist cnn
print('Minist CNN')
for i in range(len(cnn_parameters)):
    print('=====================', i ,'=====================')
    print(cnn_parameters[i])
    Mnist_cnn.network(  x_train, y_train, 
                        x_test, y_test,
                        batch_size, 
                        num_classes, 
                        epochs,
                        initializer = cnn_parameters[i][0],
                        regularizer = cnn_parameters[i][3],
                        activation = cnn_parameters[i][1],
                        optimizer = cnn_parameters[i][2],
                        dropout = cnn_parameters[i][4],
                        plot_num = i)
# Out:
# Minist CNN
# ===================== 0 =====================
# ['Ones', 'sigmoid', 'SGD', 'l1', True]
# Train loss: 3.083754539489746
# Train accuracy: 0.10000000149011612
# Test loss: 3.083749532699585
# Test accuracy: 0.10000000149011612
# ===================== 1 =====================
# ['Ones', 'relu', 'Adadelta', 'l2', True]
# Train loss: 6.053539276123047
# Train accuracy: 0.8108000159263611
# Test loss: 6.075868129730225
# Test accuracy: 0.7967000007629395
# ===================== 2 =====================
# ['Ones', 'tanh', 'Adam', 'l1', False]
# Train loss: 2.5928046703338623
# Train accuracy: 0.7799999713897705
# Test loss: 2.607872724533081
# Test accuracy: 0.7723000049591064
# ===================== 3 =====================
# ['Ones', 'softmax', 'RMSprop', 'l2', False]
# Train loss: 2.305635452270508
# Train accuracy: 0.10000000149011612
# Test loss: 2.3056347370147705
# Test accuracy: 0.10000000149011612
# ===================== 4 =====================
# ['Zeros', 'sigmoid', 'Adadelta', 'l1', False]
# Train loss: 5.490530490875244
# Train accuracy: 0.10000000149011612
# Test loss: 5.490539073944092
# Test accuracy: 0.10000000149011612
# ===================== 5 =====================
# ['Zeros', 'relu', 'SGD', 'l2', False]
# Train loss: 2.376173257827759
# Train accuracy: 0.10000000149011612
# Test loss: 2.3761746883392334
# Test accuracy: 0.10000000149011612
# ===================== 6 =====================
# ['Zeros', 'tanh', 'RMSprop', 'l1', True]
# Train loss: 8.231071472167969
# Train accuracy: 0.10000000149011612
# Test loss: 8.231077194213867
# Test accuracy: 0.10000000149011612
# ===================== 7 =====================
# ['Zeros', 'softmax', 'Adam', 'l2', True]
# Train loss: 2.3027055263519287
# Train accuracy: 0.10000000149011612
# Test loss: 2.3027045726776123
# Test accuracy: 0.10000000149011612
# ===================== 8 =====================
# ['RandomUniform', 'sigmoid', 'Adam', 'l2', False]
# Train loss: 2.3045380115509033
# Train accuracy: 0.10000000149011612
# Test loss: 2.304535388946533
# Test accuracy: 0.10000000149011612
# ===================== 9 =====================
# ['RandomUniform', 'relu', 'RMSprop', 'l1', False]
# Train loss: 6.568305492401123
# Train accuracy: 0.10000000149011612
# Test loss: 6.568302154541016
# Test accuracy: 0.10000000149011612
# ===================== 10 =====================
# ['RandomUniform', 'tanh', 'SGD', 'l2', True]
# Train loss: 0.7015005350112915
# Train accuracy: 0.848800003528595
# Test loss: 0.7272952198982239
# Test accuracy: 0.8363999724388123
# ===================== 11 =====================
# ['RandomUniform', 'softmax', 'Adadelta', 'l1', True]
# Train loss: 5.034091949462891
# Train accuracy: 0.10000000149011612
# Test loss: 5.034088611602783
# Test accuracy: 0.10000000149011612
# ===================== 12 =====================
# ['RandomNormal', 'sigmoid', 'RMSprop', 'l2', True]
# Train loss: 2.3108837604522705
# Train accuracy: 0.10000000149011612
# Test loss: 2.3108866214752197
# Test accuracy: 0.10000000149011612
# ===================== 13 =====================
# ['RandomNormal', 'relu', 'Adam', 'l1', True]
# Train loss: 3.735624313354492
# Train accuracy: 0.10000000149011612
# Test loss: 3.735625743865967
# Test accuracy: 0.10000000149011612
# ===================== 14 =====================
# ['RandomNormal', 'tanh', 'Adadelta', 'l2', False]
# Train loss: 3.125739812850952
# Train accuracy: 0.784766674041748
# Test loss: 3.1467511653900146
# Test accuracy: 0.7734000086784363
# ===================== 15 =====================
# ['RandomNormal', 'softmax', 'SGD', 'l1', False]
# Train loss: 2.9028470516204834
# Train accuracy: 0.10000000149011612
# Test loss: 2.9028501510620117
# Test accuracy: 0.10000000149011612

# %% [markdown]
# ---

# %% [markdown]
# ### Custom model

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# (x_train, y_train), (x_test, y_test) = cifar10.load_data()

batch_size = 128
num_classes = 10
epochs = 20
ini = ['Ones', 'Zeros', 'RandomUniform', 'RandomNormal']
regu = ['l1', 'l2', 'l1', 'l2']; drop = [True, True, False, False]

acti = ['sigmoid', 'relu', 'tanh', 'softmax']
opti = ['SGD', "Adadelta", 'Adam', 'RMSprop']
cnn_parameters = [ [ini[0], acti[0], opti[0], regu[0], drop[0]],
                    [ini[0], acti[1], opti[1], regu[1], drop[1]],
                    [ini[0], acti[2], opti[2], regu[2], drop[2]],
                    [ini[0], acti[3], opti[3], regu[3], drop[3]],
                    [ini[1], acti[0], opti[1], regu[2], drop[2]],
                    [ini[1], acti[1], opti[0], regu[3], drop[3]],
                    [ini[1], acti[2], opti[3], regu[0], drop[0]],
                    [ini[1], acti[3], opti[2], regu[1], drop[1]],
                    [ini[2], acti[0], opti[2], regu[3], drop[3]],
                    [ini[2], acti[1], opti[3], regu[2], drop[2]],
                    [ini[2], acti[2], opti[0], regu[1], drop[1]],
                    [ini[2], acti[3], opti[1], regu[0], drop[0]],
                    [ini[3], acti[0], opti[3], regu[1], drop[1]],
                    [ini[3], acti[1], opti[2], regu[0], drop[0]],
                    [ini[3], acti[2], opti[1], regu[3], drop[3]],
                    [ini[3], acti[3], opti[0], regu[2], drop[2]],]


# mlp_setups = ['glorot_normal', 'relu', 'rmsprop', 'l2']

# mnist cnn
print('Minist CNN')
for i in range(len(cnn_parameters)):
    print('=====================', i ,'=====================')
    print(cnn_parameters[i])
    Mnist_cnn_custom.custom_network(  x_train, y_train, 
                        x_test, y_test,
                        batch_size, 
                        num_classes, 
                        epochs,
                        initializer = cnn_parameters[i][0],
                        regularizer = cnn_parameters[i][3],
                        activation = cnn_parameters[i][1],
                        optimizer = cnn_parameters[i][2],
                        dropout = cnn_parameters[i][4],
                        plot_num = i)
# Out:
# Minist CNN
# ===================== 0 =====================
# ['Ones', 'sigmoid', 'SGD', 'l1', True]
# Train loss: 3.5212857723236084
# Train accuracy: 0.10000000149011612
# Test loss: 3.5212860107421875
# Test accuracy: 0.10000000149011612
# ===================== 1 =====================
# ['Ones', 'relu', 'Adadelta', 'l2', True]
# Train loss: 6.647053241729736
# Train accuracy: 0.8199499845504761
# Test loss: 6.670794486999512
# Test accuracy: 0.8072999715805054
# ===================== 2 =====================
# ['Ones', 'tanh', 'Adam', 'l1', False]
# Train loss: 3.5095040798187256
# Train accuracy: 0.7820166945457458
# Test loss: 3.5296382904052734
# Test accuracy: 0.7760000228881836
# ===================== 3 =====================
# ['Ones', 'softmax', 'RMSprop', 'l2', False]
# Train loss: 2.307715654373169
# Train accuracy: 0.10000000149011612
# Test loss: 2.3077123165130615
# Test accuracy: 0.10000000149011612
# ===================== 4 =====================
# ['Zeros', 'sigmoid', 'Adadelta', 'l1', False]
# Train loss: 7.210978031158447
# Train accuracy: 0.10000000149011612
# Test loss: 7.210975646972656
# Test accuracy: 0.10000000149011612
# ===================== 5 =====================
# ['Zeros', 'relu', 'SGD', 'l2', False]
# Train loss: 2.396455764770508
# Train accuracy: 0.10000000149011612
# Test loss: 2.396454334259033
# Test accuracy: 0.10000000149011612
# ===================== 6 =====================
# ['Zeros', 'tanh', 'RMSprop', 'l1', True]
# Train loss: 12.573369026184082
# Train accuracy: 0.10000000149011612
# Test loss: 12.573351860046387
# Test accuracy: 0.10000000149011612
# ===================== 7 =====================
# ['Zeros', 'softmax', 'Adam', 'l2', True]
# Train loss: 2.302753210067749
# Train accuracy: 0.10000000149011612
# Test loss: 2.302753448486328
# Test accuracy: 0.10000000149011612
# ===================== 8 =====================
# ['RandomUniform', 'sigmoid', 'Adam', 'l2', False]
# Train loss: 2.3106343746185303
# Train accuracy: 0.10000000149011612
# Test loss: 2.310633897781372
# Test accuracy: 0.10000000149011612
# ===================== 9 =====================
# ['RandomUniform', 'relu', 'RMSprop', 'l1', False]
# Train loss: 9.20540714263916
# Train accuracy: 0.10000000149011612
# Test loss: 9.205412864685059
# Test accuracy: 0.10000000149011612
# ===================== 10 =====================
# ['RandomUniform', 'tanh', 'SGD', 'l2', True]
# Train loss: 0.711625337600708
# Train accuracy: 0.8493833541870117
# Test loss: 0.7370895743370056
# Test accuracy: 0.838100016117096
# ===================== 11 =====================
# ['RandomUniform', 'softmax', 'Adadelta', 'l1', True]
# Train loss: 6.803991317749023
# Train accuracy: 0.10000000149011612
# Test loss: 6.803990840911865
# Test accuracy: 0.10000000149011612
# ===================== 12 =====================
# ['RandomNormal', 'sigmoid', 'RMSprop', 'l2', True]
# Train loss: 2.315541982650757
# Train accuracy: 0.10000000149011612
# Test loss: 2.315539836883545
# Test accuracy: 0.10000000149011612
# ===================== 13 =====================
# ['RandomNormal', 'relu', 'Adam', 'l1', True]
# Train loss: 4.765131950378418
# Train accuracy: 0.10000000149011612
# Test loss: 4.765133380889893
# Test accuracy: 0.10000000149011612
# ===================== 14 =====================
# ['RandomNormal', 'tanh', 'Adadelta', 'l2', False]
# Train loss: 3.7945432662963867
# Train accuracy: 0.7972999811172485
# Test loss: 3.8185250759124756
# Test accuracy: 0.7839999794960022
# ===================== 15 =====================
# ['RandomNormal', 'softmax', 'SGD', 'l1', False]
# Train loss: 3.3404648303985596
# Train accuracy: 0.10000000149011612
# Test loss: 3.3404855728149414
# Test accuracy: 0.10000000149011612

# %% [markdown]
# ---

# %% [markdown]
# ### Minist MLP

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# (x_train, y_train), (x_test, y_test) = cifar10.load_data()

batch_size = 128
num_classes = 10
epochs = 20

ini = ['Ones', 'Zeros', 'RandomUniform', 'RandomNormal']
regu = ['l1', 'l2', 'l1', 'l2']; drop = [True, True, False, False]

acti = ['sigmoid', 'relu', 'tanh', 'softmax']
opti = ['SGD', "Adadelta", 'Adam', 'RMSprop']
mlp_parameters = [ [ini[0], acti[0], opti[0], regu[0], drop[0]],
                    [ini[0], acti[1], opti[1], regu[1], drop[1]],
                    [ini[0], acti[2], opti[2], regu[2], drop[2]],
                    [ini[0], acti[3], opti[3], regu[3], drop[3]],
                    [ini[1], acti[0], opti[1], regu[2], drop[2]],
                    [ini[1], acti[1], opti[0], regu[3], drop[3]],
                    [ini[1], acti[2], opti[3], regu[0], drop[0]],
                    [ini[1], acti[3], opti[2], regu[1], drop[1]],
                    [ini[2], acti[0], opti[2], regu[3], drop[3]],
                    [ini[2], acti[1], opti[3], regu[2], drop[2]],
                    [ini[2], acti[2], opti[0], regu[1], drop[1]],
                    [ini[2], acti[3], opti[1], regu[0], drop[0]],
                    [ini[3], acti[0], opti[3], regu[1], drop[1]],
                    [ini[3], acti[1], opti[2], regu[0], drop[0]],
                    [ini[3], acti[2], opti[1], regu[3], drop[3]],
                    [ini[3], acti[3], opti[0], regu[2], drop[2]],]


# mlp_setups = ['glorot_normal', 'relu', 'rmsprop', 'l2']

# mnist MLP
print('Minist MLP')
for i in range(len(mlp_parameters)):
    print('=====================', i ,'=====================')
    print(mlp_parameters[i])
    Mnist_mlp.network(  x_train, y_train, 
                        x_test, y_test,
                        batch_size, 
                        num_classes, 
                        epochs,
                        initializer = mlp_parameters[i][0],
                        regularizer = mlp_parameters[i][3],
                        activation = mlp_parameters[i][1],
                        optimizer = mlp_parameters[i][2],
                        dropout = mlp_parameters[i][4],
                        plot_num = i)
# Out:
# Minist MLP
# ===================== 0 =====================
# ['Ones', 'sigmoid', 'SGD', 'l1', True]
# Train loss: 251.10328674316406
# Train accuracy: 0.10000000149011612
# Test loss: 251.1041717529297
# Test accuracy: 0.10000000149011612
# ===================== 1 =====================
# ['Ones', 'relu', 'Adadelta', 'l2', True]
# Train loss: 3726.1259765625
# Train accuracy: 0.10000000149011612
# Test loss: 3726.140869140625
# Test accuracy: 0.10000000149011612
# ===================== 2 =====================
# ['Ones', 'tanh', 'Adam', 'l1', False]
# Train loss: 3.51322603225708
# Train accuracy: 0.10000000149011612
# Test loss: 3.51322340965271
# Test accuracy: 0.10000000149011612
# ===================== 3 =====================
# ['Ones', 'softmax', 'RMSprop', 'l2', False]
# Train loss: 2.304300308227539
# Train accuracy: 0.10000000149011612
# Test loss: 2.3042991161346436
# Test accuracy: 0.10000000149011612
# ===================== 4 =====================
# ['Zeros', 'sigmoid', 'Adadelta', 'l1', False]
# Train loss: 27.205476760864258
# Train accuracy: 0.10000000149011612
# Test loss: 27.205463409423828
# Test accuracy: 0.10000000149011612
# ===================== 5 =====================
# ['Zeros', 'relu', 'SGD', 'l2', False]
# Train loss: 2.427550792694092
# Train accuracy: 0.10000000149011612
# Test loss: 2.4275460243225098
# Test accuracy: 0.10000000149011612
# ===================== 6 =====================
# ['Zeros', 'tanh', 'RMSprop', 'l1', True]
# Train loss: 5.543628692626953
# Train accuracy: 0.10000000149011612
# Test loss: 5.543630123138428
# Test accuracy: 0.10000000149011612
# ===================== 7 =====================
# ['Zeros', 'softmax', 'Adam', 'l2', True]
# Train loss: 2.3026468753814697
# Train accuracy: 0.10000000149011612
# Test loss: 2.3026480674743652
# Test accuracy: 0.10000000149011612
# ===================== 8 =====================
# ['RandomUniform', 'sigmoid', 'Adam', 'l2', False]
# Train loss: 1.7271671295166016
# Train accuracy: 0.6143166422843933
# Test loss: 1.731083631515503
# Test accuracy: 0.6176999807357788
# ===================== 9 =====================
# ['RandomUniform', 'relu', 'RMSprop', 'l1', False]
# Train loss: 5.59169864654541
# Train accuracy: 0.10000000149011612
# Test loss: 5.5916924476623535
# Test accuracy: 0.10000000149011612
# ===================== 10 =====================
# ['RandomUniform', 'tanh', 'SGD', 'l2', True]
# Train loss: 1.0608259439468384
# Train accuracy: 0.8279666900634766
# Test loss: 1.0839521884918213
# Test accuracy: 0.8147000074386597
# ===================== 11 =====================
# ['RandomUniform', 'softmax', 'Adadelta', 'l1', True]
# Train loss: 25.7391414642334
# Train accuracy: 0.10000000149011612
# Test loss: 25.739377975463867
# Test accuracy: 0.10000000149011612
# ===================== 12 =====================
# ['RandomNormal', 'sigmoid', 'RMSprop', 'l2', True]
# Train loss: 1.8174279928207397
# Train accuracy: 0.5440666675567627
# Test loss: 1.8269884586334229
# Test accuracy: 0.5436999797821045
# ===================== 13 =====================
# ['RandomNormal', 'relu', 'Adam', 'l1', True]
# Train loss: 3.1183114051818848
# Train accuracy: 0.10000000149011612
# Test loss: 3.118314743041992
# Test accuracy: 0.10000000149011612
# ===================== 14 =====================
# ['RandomNormal', 'tanh', 'Adadelta', 'l2', False]
# Train loss: 12.860248565673828
# Train accuracy: 0.7917333245277405
# Test loss: 12.878931999206543
# Test accuracy: 0.7771000266075134
# ===================== 15 =====================
# ['RandomNormal', 'softmax', 'SGD', 'l1', False]
# Train loss: 2.6369986534118652
# Train accuracy: 0.10000000149011612
# Test loss: 2.6369946002960205
# Test accuracy: 0.10000000149011612

# %% [markdown]
# ---

# %% [markdown]
# ### custom mlp

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# (x_train, y_train), (x_test, y_test) = cifar10.load_data()

batch_size = 128
num_classes = 10
epochs = 20
# RandomUniform
# tanh
# SGD
# l2
# True
ini = ['Ones', 'Zeros', 'RandomUniform', 'RandomNormal']
regu = ['l1', 'l2', 'l1', 'l2']; drop = [True, True, False, False]

acti = ['sigmoid', 'relu', 'tanh', 'softmax']
opti = ['SGD', "Adadelta", 'Adam', 'RMSprop']
mlp_parameters = [ [ini[0], acti[0], opti[0], regu[0], drop[0]],
                    [ini[0], acti[1], opti[1], regu[1], drop[1]],
                    [ini[0], acti[2], opti[2], regu[2], drop[2]],
                    [ini[0], acti[3], opti[3], regu[3], drop[3]],
                    [ini[1], acti[0], opti[1], regu[2], drop[2]],
                    [ini[1], acti[1], opti[0], regu[3], drop[3]],
                    [ini[1], acti[2], opti[3], regu[0], drop[0]],
                    [ini[1], acti[3], opti[2], regu[1], drop[1]],
                    [ini[2], acti[0], opti[2], regu[3], drop[3]],
                    [ini[2], acti[1], opti[3], regu[2], drop[2]],
                    [ini[2], acti[2], opti[0], regu[1], drop[1]],
                    [ini[2], acti[3], opti[1], regu[0], drop[0]],
                    [ini[3], acti[0], opti[3], regu[1], drop[1]],
                    [ini[3], acti[1], opti[2], regu[0], drop[0]],
                    [ini[3], acti[2], opti[1], regu[3], drop[3]],
                    [ini[3], acti[3], opti[0], regu[2], drop[2]],]


# mlp_setups = ['glorot_normal', 'relu', 'rmsprop', 'l2']

# mnist MLP
print('Minist MLP')
for i in range(len(mlp_parameters)):
    print('=====================', i ,'=====================')
    print(mlp_parameters[i])
    Mnist_mlp_custom.custom_network(  x_train, y_train, 
                        x_test, y_test,
                        batch_size, 
                        num_classes, 
                        epochs,
                        initializer = mlp_parameters[i][0],
                        regularizer = mlp_parameters[i][3],
                        activation = mlp_parameters[i][1],
                        optimizer = mlp_parameters[i][2],
                        dropout = mlp_parameters[i][4],
                        plot_num = i)
# Out:
# Minist MLP
# ===================== 0 =====================
# ['Ones', 'sigmoid', 'SGD', 'l1', True]
# Train loss: 251.235107421875
# Train accuracy: 0.10000000149011612
# Test loss: 251.2348175048828
# Test accuracy: 0.10000000149011612
# ===================== 1 =====================
# ['Ones', 'relu', 'Adadelta', 'l2', True]
# Train loss: 3710.902587890625
# Train accuracy: 0.10000000149011612
# Test loss: 3710.92919921875
# Test accuracy: 0.10000000149011612
# ===================== 2 =====================
# ['Ones', 'tanh', 'Adam', 'l1', False]
# Train loss: 3.866636276245117
# Train accuracy: 0.10000000149011612
# Test loss: 3.8666319847106934
# Test accuracy: 0.10000000149011612
# ===================== 3 =====================
# ['Ones', 'softmax', 'RMSprop', 'l2', False]
# Train loss: 2.3049139976501465
# Train accuracy: 0.10000000149011612
# Test loss: 2.304913282394409
# Test accuracy: 0.10000000149011612
# ===================== 4 =====================
# ['Zeros', 'sigmoid', 'Adadelta', 'l1', False]
# Train loss: 47.14458465576172
# Train accuracy: 0.10000000149011612
# Test loss: 47.1445426940918
# Test accuracy: 0.10000000149011612
# ===================== 5 =====================
# ['Zeros', 'relu', 'SGD', 'l2', False]
# Train loss: 2.547497510910034
# Train accuracy: 0.10000000149011612
# Test loss: 2.5475025177001953
# Test accuracy: 0.10000000149011612
# ===================== 6 =====================
# ['Zeros', 'tanh', 'RMSprop', 'l1', True]
# Train loss: 6.816294193267822
# Train accuracy: 0.10000000149011612
# Test loss: 6.816299915313721
# Test accuracy: 0.10000000149011612
# ===================== 7 =====================
# ['Zeros', 'softmax', 'Adam', 'l2', True]
# Train loss: 2.3026671409606934
# Train accuracy: 0.10000000149011612
# Test loss: 2.3026647567749023
# Test accuracy: 0.10000000149011612
# ===================== 8 =====================
# ['RandomUniform', 'sigmoid', 'Adam', 'l2', False]
# Train loss: 2.3062007427215576
# Train accuracy: 0.10000000149011612
# Test loss: 2.306199550628662
# Test accuracy: 0.10000000149011612
# ===================== 9 =====================
# ['RandomUniform', 'relu', 'RMSprop', 'l1', False]
# Train loss: 6.793797492980957
# Train accuracy: 0.10000000149011612
# Test loss: 6.793790817260742
# Test accuracy: 0.10000000149011612
# ===================== 10 =====================
# ['RandomUniform', 'tanh', 'SGD', 'l2', True]
# Train loss: 1.2430088520050049
# Train accuracy: 0.8264333605766296
# Test loss: 1.2671477794647217
# Test accuracy: 0.815500020980835
# ===================== 11 =====================
# ['RandomUniform', 'softmax', 'Adadelta', 'l1', True]
# Train loss: 45.92546081542969
# Train accuracy: 0.10000000149011612
# Test loss: 45.92572021484375
# Test accuracy: 0.10000000149011612
# ===================== 12 =====================
# ['RandomNormal', 'sigmoid', 'RMSprop', 'l2', True]
# Train loss: 2.317558765411377
# Train accuracy: 0.10000000149011612
# Test loss: 2.3175597190856934
# Test accuracy: 0.10000000149011612
# ===================== 13 =====================
# ['RandomNormal', 'relu', 'Adam', 'l1', True]
# Train loss: 3.459259271621704
# Train accuracy: 0.10000000149011612
# Test loss: 3.4592583179473877
# Test accuracy: 0.10000000149011612
# ===================== 14 =====================
# ['RandomNormal', 'tanh', 'Adadelta', 'l2', False]
# Train loss: 16.715700149536133
# Train accuracy: 0.8005499839782715
# Test loss: 16.738399505615234
# Test accuracy: 0.7901999950408936
# ===================== 15 =====================
# ['RandomNormal', 'softmax', 'SGD', 'l1', False]
# Train loss: 2.7683639526367188
# Train accuracy: 0.10000000149011612
# Test loss: 2.768359422683716
# Test accuracy: 0.10000000149011612

# %%
batch_size = 32
num_classes = 10
epochs = 20

mlp_parameters = [  ['RandomUniform', 'l2', 'relu', 'SGD'],
                    ['RandomUniform', 'l2', 'relu', 'Adam']]


# mlp_setups = ['glorot_normal', 'relu', 'rmsprop', 'l2']

# mnist MLP
print('Minist MLP')
for i in range(len(mlp_parameters)):
    print('=====================', i ,'=====================')
    print(mlp_parameters[i])
    Mnist_mlp.network(  x_train, y_train, 
                        x_test, y_test,
                        batch_size, 
                        num_classes, 
                        epochs,
                        initializer = mlp_parameters[i][0],
                        regularizer = mlp_parameters[i][1],
                        activation = mlp_parameters[i][2],
                        optimizer = mlp_parameters[i][3],
                        plot_num = i)
# Out:
# Minist MLP
# ===================== 0 =====================
# ['RandomUniform', 'l2', 'relu', 'SGD']
# Test loss: 0.865041971206665
# Test accuracy: 0.8141999840736389
# ===================== 1 =====================
# ['RandomUniform', 'l2', 'relu', 'Adam']
# Test loss: 0.9749014377593994
# Test accuracy: 0.7545999884605408

# %% [markdown]
# ---

# %% [markdown]
# ### CIFAR-10 cnn

# %%
batch_size = 32
num_classes = 10
epochs = 20

cnn_parameters = [  ['RandomUniform', 'l2', 'relu', 'SGD'],
                    ['RandomUniform', 'l2', 'relu', 'Adam']]


# mlp_setups = ['glorot_normal', 'relu', 'rmsprop', 'l2']

# mnist cnn
print('Minist CNN')
for i in range(len(cnn_parameters)):
    j = i + 10
    print('=====================', i ,'=====================')
    print(cnn_parameters[i])
    Cifar10_cnn.network(  x_train, y_train, 
                        x_test, y_test,
                        batch_size, 
                        num_classes, 
                        epochs,
                        initializer = cnn_parameters[i][0],
                        regularizer = cnn_parameters[i][1],
                        activation = cnn_parameters[i][2],
                        optimizer = cnn_parameters[i][3],
                        plot_num = j)

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
batch_size = 32
num_classes = 10
epochs = 20

cnn_parameters = [  ['RandomUniform', 'l2', 'relu', 'SGD'],
                    ['RandomUniform', 'l2', 'relu', 'Adam']]


# mlp_setups = ['glorot_normal', 'relu', 'rmsprop', 'l2']

# mnist cnn
print('Minist CNN')
for i in range(len(cnn_parameters)):
    j = i + 10
    print('=====================', i ,'=====================')
    print(cnn_parameters[i])
    Cifar10_cnn.network(  x_train, y_train, 
                        x_test, y_test,
                        batch_size, 
                        num_classes, 
                        epochs,
                        initializer = cnn_parameters[i][0],
                        regularizer = cnn_parameters[i][1],
                        activation = cnn_parameters[i][2],
                        optimizer = cnn_parameters[i][3],
                        plot_num = j)
# Out:
# Minist CNN
# ===================== 0 =====================
# ['RandomUniform', 'l2', 'relu', 'SGD']
# Test loss: 1.6433113813400269
# Test accuracy: 0.5321999788284302
# ===================== 1 =====================
# ['RandomUniform', 'l2', 'relu', 'Adam']
# Test loss: 1.826419711112976
# Test accuracy: 0.4332999885082245

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
batch_size = 128
num_classes = 10
epochs = 20

cnn_parameters = [  ['RandomUniform', 'l2', 'relu', 'SGD'],
                    ['RandomUniform', 'l2', 'relu', 'Adam']]


# mlp_setups = ['glorot_normal', 'relu', 'rmsprop', 'l2']

# mnist cnn
print('Minist CNN')
for i in range(len(cnn_parameters)):
    j = i + 10
    print('=====================', i ,'=====================')
    print(cnn_parameters[i])
    Cifar10_cnn.network(  x_train, y_train, 
                        x_test, y_test,
                        batch_size, 
                        num_classes, 
                        epochs,
                        initializer = cnn_parameters[i][0],
                        regularizer = cnn_parameters[i][1],
                        activation = cnn_parameters[i][2],
                        optimizer = cnn_parameters[i][3],
                        plot_num = j)
# Out:
# Minist CNN
# ===================== 0 =====================
# ['RandomUniform', 'l2', 'relu', 'SGD']
# Test loss: 1.8171521425247192
# Test accuracy: 0.46939998865127563
# ===================== 1 =====================
# ['RandomUniform', 'l2', 'relu', 'Adam']
# Test loss: 1.7023375034332275
# Test accuracy: 0.4952999949455261

# %% [markdown]
# ---

# %% [markdown]
# ### Model Structure

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D

# %% [markdown]
# #### MINIST CNN

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='PReLU',
                 input_shape=(28, 28, 1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 26, 26, 32)        21952
#
#  conv2d_9 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 12, 12, 64)        0
#
#  flatten_3 (Flatten)         (None, 9216)              0
#
#  dense_5 (Dense)             (None, 128)               1179776
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,221,514
# Trainable params: 1,221,514
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### MINIST MLP

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 512)               401920
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_8 (Dense)             (None, 512)               262656
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_9 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### MINIST Custom CNN

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='PReLU',
                 input_shape=(28, 28, 1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 26, 26, 32)        21952
#
#  conv2d_11 (Conv2D)          (None, 24, 24, 64)        18496
#
#  conv2d_12 (Conv2D)          (None, 22, 22, 128)       73856
#
#  max_pooling2d_4 (MaxPooling  (None, 11, 11, 128)      0
#  2D)
#
#  dropout_10 (Dropout)        (None, 11, 11, 128)       0
#
#  flatten_4 (Flatten)         (None, 15488)             0
#
#  dense_10 (Dense)            (None, 128)               1982592
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_11 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 2,098,186
# Trainable params: 2,098,186
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### MINIST Custom MLP

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 512)               401920
#
#  dropout_12 (Dropout)        (None, 512)               0
#
#  dense_13 (Dense)            (None, 512)               262656
#
#  dropout_13 (Dropout)        (None, 512)               0
#
#  dense_14 (Dense)            (None, 512)               262656
#
#  dropout_14 (Dropout)        (None, 512)               0
#
#  dense_15 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 932,362
# Trainable params: 932,362
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### CIFAR CNN

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='PReLU',
                 input_shape=(32, 32, 3)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_13 (Conv2D)          (None, 30, 30, 32)        29696
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  dropout_15 (Dropout)        (None, 14, 14, 64)        0
#
#  flatten_5 (Flatten)         (None, 12544)             0
#
#  dense_16 (Dense)            (None, 128)               1605760
#
#  dropout_16 (Dropout)        (None, 128)               0
#
#  dense_17 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 1,655,242
# Trainable params: 1,655,242
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### CIFAR MLP

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(1024 * 3,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 512)               1573376
#
#  dropout_17 (Dropout)        (None, 512)               0
#
#  dense_19 (Dense)            (None, 512)               262656
#
#  dropout_18 (Dropout)        (None, 512)               0
#
#  dense_20 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### CIFAR custom CNN

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='PReLU',
                 input_shape=(32, 32, 3)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 30, 30, 32)        29696
#
#  conv2d_16 (Conv2D)          (None, 28, 28, 64)        18496
#
#  conv2d_17 (Conv2D)          (None, 26, 26, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  dropout_19 (Dropout)        (None, 13, 13, 128)       0
#
#  flatten_6 (Flatten)         (None, 21632)             0
#
#  dense_21 (Dense)            (None, 128)               2769024
#
#  dropout_20 (Dropout)        (None, 128)               0
#
#  dense_22 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 2,892,362
# Trainable params: 2,892,362
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### CIFAR custom MLP

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(1024 * 3,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_23 (Dense)            (None, 512)               1573376
#
#  dropout_21 (Dropout)        (None, 512)               0
#
#  dense_24 (Dense)            (None, 512)               262656
#
#  dropout_22 (Dropout)        (None, 512)               0
#
#  dense_25 (Dense)            (None, 512)               262656
#
#  dropout_23 (Dropout)        (None, 512)               0
#
#  dense_26 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 2,103,818
# Trainable params: 2,103,818
# Non-trainable params: 0
# _________________________________________________________________
