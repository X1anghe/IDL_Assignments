# %% [markdown]
# ### visialization and gamma enhance (images.npy)

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import exposure

# %%
imgs = np.load('../Datasets/Input/images.npy')    #使用numpy载入npy文件
labels = np.load('../Datasets/Input/labels.npy')    #使用numpy载入npy文件

# %%
print(labels[0])
gamma_transfer = exposure.adjust_gamma(imgs[0], 3)
plt.subplot(1, 2, 1)
plt.imshow(gamma_transfer, cmap ='gray')
plt.subplot(1, 2, 2)
plt.imshow(imgs[0], cmap ='gray')
# Out:
# [0 0]

# %% [markdown]
# ### Data preprocessing
